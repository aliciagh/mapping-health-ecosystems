# %%
# -*- coding: utf-8 -*-
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 20)


import numpy as np

from scipy import stats

from bokeh.io import show, output_file
from bokeh.plotting import figure

 
# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds']
creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
client = gspread.authorize(creds)

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20b
from bokeh.models import LabelSet
import math

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="29ed6d53-2be6-406a-9cf4-6f28a336a480">Loading BokehJS ...</span>
#     </div>

# %%
spreadsheet = client.open_by_key("13Mc2sWnyQ-TeALOnKVohyGm9dokgCWDA7IVF5fNjZ8I")
sheetFinalResults = spreadsheet.get_worksheet(3)

# %%
#list_of_hashesA = sheetA1.get_all_records()
#print(list_of_hashes)

data = pd.DataFrame(sheetFinalResults.get_all_records())

print("Number of papers resulting the mapping: ", len(data))
# Out:
# Number of papers resulting the mapping:  19

# %%
display(data.head())
# Out:
#                                             Abstract      Acronym  \
# 0  The PAMAP system comprises two separate concep...        PAMAP
# 1  The project comprises entities from different ...  DIET4Elders
# 2  HEREiAM aims to promote elderly people’s indep...      HEREiAM
# 3  Go-myLife aims to improve the quality of life ...   GO-MY LIFE
# 4  The project builds an ecosystem for collaborat...   Elders-UP!
#
#                        Aditional Information Sources Call  Call year  \
# 0                           10.1109/TrustCom.2012.81            2008
# 1  https://www.aalforum.eu/wp-content/uploads/201...            2012
# 2                       10.1007/978-3-319-01583-5_63            2012
# 3  http://delivery.acm.org/10.1145/2510000/250434...            2009
# 4                                                               2013
#
#                                            Countries  \
# 0           Germany, Greece, France, Germany, France
# 1  Spain, United Kingdom, Spain, United Kingdom, ...
# 2  Italy, Italy, Belgium, Romania, Italy, The Net...
# 3  Spain, United Kingdom, Greece, Austria, United...
# 4  Spain,Spain,Cyprus,Romania,United Kingdom,Cypr...
#
#                                          Description          Domain  \
# 0  Information management system for monitoring a...  Rehabilitation
# 1  platfrom with analysis of AAL, connection with...       Nutrition
# 2  service platform that can vary depending on th...     Well-ageing
# 3  Social network  ecosystem to help older people...     Well-ageing
# 4  Ecosystem for collaboration between SMEs and s...     Well-ageing
#
#   Domain details    End date               ...                 \
# 0                 01/07/2012               ...
# 1                 01/07/2016               ...
# 2                 01/07/2016               ...
# 3                 01/01/2013               ...
# 4                 01/01/2017               ...
#
#                 Programme       Reference  \
# 0  Call 1 - AAL PROGRAMME  AAL-2008-1-162
# 1  Call 5 - AAL PROGRAMME  AAL-2012-5-195
# 2  Call 5 - AAL PROGRAMME  AAL-2012-5-064
# 3  Call 2 - AAL PROGRAMME  AAL-2009-2-089
# 4  Call 6 - AAL PROGRAMME  AAL-2013-6-131
#
#                                    Stakeholders  Start date  \
# 0      Patients, Nurse, Care planner, Physician  01/07/2009
# 1  Older persons, Informal carers, Nutritionist  01/07/2013
# 2                Older persons, Informal carers  01/07/2013
# 3                  Older persons, Organizations  01/07/2010
# 4                           Older persons, SMEs  01/07/2014
#
#                                                Title Total budget (€)  \
# 0      Physical Activity Monitoring for Aging People        2.771.929
# 1  Dynamic nutrItion bEhaviour awareness sysTem F...     2.005.433,00
# 2  An interoperable platform for self care, socia...        3.374.658
# 3                     Going on line: my social Life         2.400.000
# 4  Adaptive system for enabling the elderly colla...     2.101.036,47
#
#   Type of ecosystem (mobile, web, sensors, ...)  \
# 0                         sensors + mobile + tv
# 1                                 web + sensors
# 2                         mobile + tv + sensors
# 3                                           web
# 4                                           web
#
#                                 Type of institutions  \
# 0                       R&D, R&D, R&D, SME, End-user
# 1                  SME, Business, End-user, R&D, R&D
# 2  R&D, Business, SME, Business, SME, SME, End-us...
# 3             Business, SME, R&D, R&D, SME, SME, SME
# 4          SME,SME,SME,R&D,SME,End-user,End-user,SME
#
#                                               URL  \
# 0               www.aal-europe.eu/projects/pamap/
# 1  http://www.aal-europe.eu/projects/diet4elders/
# 2      http://www.aal-europe.eu/projects/hereiam/
# 3   http://www.aal-europe.eu/projects/go-my-life/
# 4     http://www.aal-europe.eu/projects/eldersup/
#
#                                Web
# 0             http://www.pamap.org
# 1     http://www.diet4elders.eu/en
# 2   http://www.hereiamproject.org/
# 3  http://www.gomylife-project.eu/
# 4      http://www.eldersup-aal.eu/
#
# [5 rows x 25 columns]

# %%
domains = data["Domain"].values
domains_list = []
for domain in domains:
    [domains_list.append(x.strip()) for x in domain.split(',')]
    
domains_list = [x for x in domains_list if x != '']
display(domains_list)

dfDomains = pd.DataFrame(domains_list)
# Out:
# ['Rehabilitation',
#  'Nutrition',
#  'Well-ageing',
#  'Well-ageing',
#  'Well-ageing',
#  'Independent living',
#  'Well-ageing',
#  'Independent living',
#  'Independent living',
#  'Well-ageing',
#  'Healthcare',
#  'Well-ageing',
#  'Independent living',
#  'Assistive services',
#  'Healthcare',
#  'Biotechnology',
#  'Healthcare',
#  'Healthcare',
#  'Healthcare',
#  'Biotechnology',
#  'Rare diseases']

# %%
display(dfDomains)
# Out:
#                      0
# 0       Rehabilitation
# 1            Nutrition
# 2          Well-ageing
# 3          Well-ageing
# 4          Well-ageing
# 5   Independent living
# 6          Well-ageing
# 7   Independent living
# 8   Independent living
# 9          Well-ageing
# 10          Healthcare
# 11         Well-ageing
# 12  Independent living
# 13  Assistive services
# 14          Healthcare
# 15       Biotechnology
# 16          Healthcare
# 17          Healthcare
# 18          Healthcare
# 19       Biotechnology
# 20       Rare diseases

# %%
dfDomains.columns = ['Term']
resultsDomains = pd.DataFrame(dfDomains['Term'].value_counts())
display(resultsDomains)
# Out:
#                     Term
# Well-ageing            6
# Healthcare             5
# Independent living     4
# Biotechnology          2
# Rare diseases          1
# Rehabilitation         1
# Nutrition              1
# Assistive services     1

# %%
resultsDomains.reset_index(level=0, inplace=True)
resultsDomains.columns = ['Term', 'Count']

resultsDomains.sort_values(['Term', 'Count'], ascending=[True, False], inplace=True)
display(resultsDomains)
# Out:
#                  Term  Count
# 7  Assistive services      1
# 3       Biotechnology      2
# 1          Healthcare      5
# 2  Independent living      4
# 6           Nutrition      1
# 4       Rare diseases      1
# 5      Rehabilitation      1
# 0         Well-ageing      6

# %%
# output_file('vbar.html')

p = figure(x_range=resultsDomains['Term'].tolist(), toolbar_location=None, title="Domain Counts")
p.vbar(x=resultsDomains['Term'].tolist(), top=resultsDomains['Count'].tolist(), width=0.6)
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 8
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="16fc9456-1058-48c5-b9f0-f6f9141efaf6"></div>
# </div>

# %%
institutions = data["Type of institutions"].values
institutions_list = []
for institution in institutions:
    [institutions_list.append(x.strip()) for x in institution.split(',')]
    
institutions_list = [x for x in institutions_list if x != '']
# display(authors_list)

dfTypeIns = pd.DataFrame(institutions_list)
dfTypeIns.columns = ['Type']
display(dfTypeIns)
# Out:
#                   Type
# 0                  R&D
# 1                  R&D
# 2                  R&D
# 3                  SME
# 4             End-user
# 5                  SME
# 6             Business
# 7             End-user
# 8                  R&D
# 9                  R&D
# 10                 R&D
# 11            Business
# 12                 SME
# 13            Business
# 14                 SME
# 15                 SME
# 16            End-user
# 17            End-user
# 18            Business
# 19                 SME
# 20                 R&D
# 21                 R&D
# 22                 SME
# 23                 SME
# 24                 SME
# 25                 SME
# 26                 SME
# 27                 SME
# 28                 R&D
# 29                 SME
# 30            End-user
# 31            End-user
# 32                 SME
# 33                 R&D
# 34            End-user
# 35                 R&D
# 36                 R&D
# 37            End-user
# 38                 SME
# 39                 SME
# 40            End-user
# 41            End-user
# 42                 SME
# 43                 R&D
# 44                 SME
# 45                 SME
# 46                 R&D
# 47                 SME
# 48                 R&D
# 49            End-user
# 50                 SME
# 51            Business
# 52                 R&D
# 53                 R&D
# 54            End-user
# 55                 SME
# 56                 R&D
# 57                 SME
# 58                 SME
# 59                 SME
# 60            End-user
# 61                 SME
# 62            End-user
# 63            End-user
# 64                 R&D
# 65            End-user
# 66                 SME
# 67                 SME
# 68            End-user
# 69                 SME
# 70                 SME
# 71            End-user
# 72                 R&D
# 73                 R&D
# 74            End-user
# 75                 SME
# 76            End-user
# 77                 R&D
# 78                 SME
# 79                 SME
# 80                 LAE
# 81            End-user
# 82                 SME
# 83            End-user
# 84                 SME
# 85                 SME
# 86            End-user
# 87                 R&D
# 88                 SME
# 89                 R&D
# 90                 R&D
# 91                 R&D
# 92                 R&D
# 93                 R&D
# 94                 R&D
# 95                 R&D
# 96                 R&D
# 97                 R&D
# 98                 R&D
# 99                 R&D
# 100                R&D
# 101                R&D
# 102                R&D
# 103                R&D
# 104                R&D
# 105                R&D
# 106                R&D
# 107                R&D
# 108                R&D
# 109                R&D
# 110                R&D
# 111                R&D
# 112                R&D
# 113                R&D
# 114                R&D
# 115                R&D
# 116                R&D
# 117                R&D
# 118                R&D
# 119                R&D
# 120                R&D
# 121                R&D
# 122                R&D
# 123                R&D
# 124                R&D
# 125                R&D
# 126                R&D
# 127                R&D
# 128                R&D
# 129                R&D
# 130                R&D
# 131                R&D
# 132                R&D
# 133                R&D
# 134                R&D
# 135                R&D
# 136                R&D
# 137                R&D
# 138                R&D
# 139                R&D
# 140                R&D
# 141                R&D
# 142                R&D
# 143                R&D
# 144                R&D
# 145                SME
# 146                R&D
# 147                R&D
# 148                R&D
# 149                R&D
# 150           Business
# 151                R&D
# 152                R&D
# 153                SME
# 154                R&D
# 155                SME
# 156                R&D
# 157                R&D
# 158                R&D
# 159           Business
# 160           End-user
# 161                SME
# 162                SME
# 163                R&D
# 164           End-user
# 165           Business
# 166                SME
# 167                R&D
# 168                R&D
# 169                R&D
# 170           End-user
# 171                SME
# 172                SME
# 173           End-user
# 174                R&D
# 175                R&D
# 176                R&D
# 177                R&D
# 178                R&D
# 179                R&D
# 180                R&D
# 181                R&D
# 182                R&D
# 183                R&D
# 184                SME
# 185                R&D
# 186                R&D
# 187                R&D
# 188                SME
# 189                R&D
# 190                R&D
# 191                R&D
# 192                R&D
# 193                R&D
# 194                R&D
# 195                R&D
# 196           End-user
# 197                R&D
# 198           Business
# 199                R&D
# 200                R&D
# 201           End-user
# 202                R&D
# 203                R&D
# 204           Business
# 205           End-user
# 206                R&D
# 207           Business
# 208  Multi-stakeholder
# 209           Business
# 210                R&D
# 211                R&D

# %%
resultsTypeIns = pd.DataFrame(dfTypeIns['Type'].value_counts())
# display(resultsAuthors)
resultsTypeIns.reset_index(level=0, inplace=True)
resultsTypeIns.columns = ['Type', 'Count']

display(resultsTypeIns)
# Out:
#                 Type  Count
# 0                R&D    121
# 1                SME     47
# 2           End-user     30
# 3           Business     12
# 4  Multi-stakeholder      1
# 5                LAE      1

# %%
p = figure(x_range=resultsTypeIns['Type'].tolist(), toolbar_location=None, title="Type of institutions")
p.vbar(x=resultsTypeIns['Type'].tolist(), top=resultsTypeIns['Count'].tolist(), width=0.6)
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 125
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="eba82f3c-211f-4edb-a25f-8d287bfdea4c"></div>
# </div>

# %%
pieInst = pd.DataFrame(resultsTypeIns['Count'].tolist(), columns=["Type of institutions"])
pieInst.plot.pie(subplots=True, labels=resultsTypeIns['Type'].tolist(), autopct='%.2f%%', fontsize=12, figsize=(6, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a0a7b9940>],
#       dtype=object)

# %%
stakeholders = data["Stakeholders"].values
stakeholders_list = []
for stakeholder in stakeholders:
    [stakeholders_list.append(x.strip()) for x in stakeholder.split(',')]
    
stakeholders_list = [x for x in stakeholders_list if x != '']
# display(authors_list)

dfStakeholder = pd.DataFrame(stakeholders_list)
dfStakeholder.columns = ['Type']
display(dfStakeholder)
# Out:
#                        Type
# 0                  Patients
# 1                     Nurse
# 2              Care planner
# 3                 Physician
# 4             Older persons
# 5           Informal carers
# 6              Nutritionist
# 7             Older persons
# 8           Informal carers
# 9             Older persons
# 10            Organizations
# 11            Older persons
# 12                     SMEs
# 13            Older persons
# 14  Health device companies
# 15            Older persons
# 16  Health device companies
# 17            Older persons
# 18            Formal carers
# 19          Informal carers
# 20      Software developers
# 21            Older persons
# 22            Older persons
# 23            Formal carers
# 24          Informal carers
# 25            Older persons
# 26          Informal carers
# 27      Software developers
# 28            Older persons
# 29          Informal carers
# 30                 Patients
# 31                  Doctors
# 32               Scientists
# 33                 Patients
# 34                  Doctors
# 35               Scientists
# 36               Consulting
# 37           Pharmaceutical
# 38    ICT solution provider
# 39    ICT solution provider
# 40        Software provider
# 41           Pharmaceutical
# 42              Consultancy
# 43        Software provider
# 44        Software provider
# 45        Software provider
# 46        Medical Equipment
# 47        Medical Equipment
# 48           Pharmaceutical
# 49                 Business
# 50           Pharmaceutical
# 51        Software provider
# 52          Pharmaceuticals
# 53                 Patients
# 54               Scientists
# 55                  Doctors

# %%
resultsStakeholders = pd.DataFrame(dfStakeholder['Type'].value_counts())

resultsStakeholders.reset_index(level=0, inplace=True)
resultsStakeholders.columns = ['Type', 'Count']

display(resultsStakeholders)
# Out:
#                        Type  Count
# 0             Older persons     11
# 1           Informal carers      6
# 2         Software provider      5
# 3            Pharmaceutical      4
# 4                  Patients      4
# 5                   Doctors      3
# 6                Scientists      3
# 7     ICT solution provider      2
# 8         Medical Equipment      2
# 9       Software developers      2
# 10            Formal carers      2
# 11  Health device companies      2
# 12              Consultancy      1
# 13             Care planner      1
# 14                    Nurse      1
# 15            Organizations      1
# 16               Consulting      1
# 17                 Business      1
# 18                Physician      1
# 19          Pharmaceuticals      1
# 20                     SMEs      1
# 21             Nutritionist      1

# %%
p = figure(x_range=resultsStakeholders['Type'].tolist(), toolbar_location=None, title="Stakeholders")
p.vbar(x=resultsStakeholders['Type'].tolist(), top=resultsStakeholders['Count'].tolist(), width=0.6)
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 12
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="707377d0-54ec-4783-8812-595191c58f1e"></div>
# </div>

# %%
programmes = data["Programme"].values
programmes_list = []
for programme in programmes:
    [programmes_list.append(x.strip()) for x in programme.split(',')]
    
programmes_list = [x for x in programmes_list if x != '']

dfProgrammes = pd.DataFrame(programmes_list)
dfProgrammes.columns = ['Name']
display(dfProgrammes)
# Out:
#                          Name
# 0      Call 1 - AAL PROGRAMME
# 1      Call 5 - AAL PROGRAMME
# 2      Call 5 - AAL PROGRAMME
# 3      Call 2 - AAL PROGRAMME
# 4      Call 6 - AAL PROGRAMME
# 5   Call 2014 - AAL PROGRAMME
# 6   Call 2014 - AAL PROGRAMME
# 7   Call 2014 - AAL PROGRAMME
# 8   Call 2014 - AAL PROGRAMME
# 9   Call 2014 - AAL PROGRAMME
# 10  Call 2014 - AAL PROGRAMME
# 11  Call 2014 - AAL PROGRAMME
# 12                 FP7-HEALTH
# 13                 FP7-HEALTH
# 14                    FP7-ICT
# 15                    FP7-ICT
# 16                    FP7-ICT
# 17          FP6-LIFESCIHEALTH
# 18          FP6-LIFESCIHEALTH

# %%
resultsProgrammes = pd.DataFrame(dfProgrammes['Name'].value_counts())
# display(resultsProgrammes)
resultsProgrammes.reset_index(level=0, inplace=True)
resultsProgrammes.columns = ['Name', 'Count']

display(resultsProgrammes)
# Out:
#                         Name  Count
# 0  Call 2014 - AAL PROGRAMME      7
# 1                    FP7-ICT      3
# 2                 FP7-HEALTH      2
# 3     Call 5 - AAL PROGRAMME      2
# 4          FP6-LIFESCIHEALTH      2
# 5     Call 2 - AAL PROGRAMME      1
# 6     Call 6 - AAL PROGRAMME      1
# 7     Call 1 - AAL PROGRAMME      1

# %%
pieProgramme = pd.DataFrame(resultsProgrammes['Count'].tolist(), columns=[""])
pieProgramme.plot.pie(subplots=True, labels=resultsProgrammes['Name'].tolist(), legend=True, colormap="Set3", autopct='%.2f%%', fontsize=12, figsize=(10, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a12c87710>],
#       dtype=object)

# %%
resultsYears = pd.DataFrame(data['Call year'].value_counts())
resultsYears.reset_index(level=0, inplace=True)
resultsYears.columns = ['Year', 'Count']
resultsYears.sort_values(['Year', 'Count'], ascending=[False, False], inplace=True)
display(resultsYears)
# Out:
#    Year  Count
# 0  2014      7
# 4  2013      1
# 2  2012      2
# 3  2010      2
# 1  2009      4
# 5  2008      1
# 6  2004      1
# 7  2002      1

# %%
pieCYear = pd.DataFrame(resultsYears['Count'].tolist(), columns=[""])
explode = (0, 0, 0, 0.1, 0.1, 0.2, 0.3, 0.4)
pieCYear.plot.pie(subplots=True, labels=resultsYears['Year'].tolist(), legend=False, colormap="Set2", explode=explode, autopct='%.2f%%', fontsize=12, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a12f0f898>],
#       dtype=object)
